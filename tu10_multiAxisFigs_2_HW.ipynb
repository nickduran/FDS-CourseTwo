# %% [markdown]
# # Tutorial 10 homework

# %% [markdown]
# In this homework, you'll make a figure containing a scatter plot with marginal histograms similar to what we made earlier. Now, however, we have a few more tools at our disposal so we can probably make a better figure.

# %% [markdown]
# Here is some code to make a simulated data consisting of the scores on two tests (A and B) taken by 100 people.

# %%
import numpy as np

my_rng = np.random.default_rng(seed = 42)
test_a = my_rng.normal(100, 15, 100)
test_b = test_a + my_rng.normal(0, 10, test_a.shape)

# %% [markdown]
# Let's make a figure featuring a scatter plot of the scores against one another, along with two supporting panels showing the histograms of the two test scores.

# %% [markdown]
# An example figure would look something like this:
#
# ![hw example figure](images/hw10example.png)
#
# **Your job is to reproduce this figure, and then improve it.**
#
# Get the layout and the three panels working first, so that your figure does what this one
# does. Then make it your own — better labels, different colors, a clearer title, whatever
# you think it needs. It does not have to match pixel for pixel, and the improvements can be
# small.
#
# A few things to hold onto:
#
# - **Use the `test_a` and `test_b` you just made above.** Don't generate new data — everyone's
#   figure should be showing the same 100 people.
# - **Every technique this figure needs, you have already seen.** The panel layout and the
#   empty corner are in today's pre-class tutorial; the sideways histogram and flipping an
#   axis are from last Thursday. Go back and look rather than starting from scratch.
# - **One piece comes from class today**, so if you are stuck on getting text onto a
#   particular panel, that is the part we cover together.
